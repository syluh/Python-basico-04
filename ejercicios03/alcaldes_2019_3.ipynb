# %%
import pandas as pd
import ipywidgets as widgets

# %%
datos_alcaldes = pd.read_csv('data/datos_alcaldes_2019_modificado.csv', sep="|")

# %%
datos_alcaldes
# Out:
#        DIGNIDAD_CODIGO DIGNIDAD_NOMBRE  PROVINCIA_CODIGO PROVINCIA_NOMBRE  \
# 0                  4.0         ALCALDE               1.0            AZUAY
# 1                  4.0         ALCALDE               1.0            AZUAY
# 2                  4.0         ALCALDE               1.0            AZUAY
# 3                  4.0         ALCALDE               1.0            AZUAY
# 4                  4.0         ALCALDE               1.0            AZUAY
# ...                ...             ...               ...              ...
# 23665              4.0         ALCALDE              24.0      SANTA ELENA
# 23666              4.0         ALCALDE              24.0      SANTA ELENA
# 23667              4.0         ALCALDE              24.0      SANTA ELENA
# 23668              4.0         ALCALDE              24.0      SANTA ELENA
# 23669              4.0         ALCALDE              24.0      SANTA ELENA
#
#        CANTON_CODIGO CANTON_NOMBRE  CIRCUNSCRIPCION_CODIGO  \
# ...

# %%
opciones = [(d, d) for d in datos_alcaldes.CANTON_NOMBRE.unique()]
opciones.sort()

"""
lista_op = []
for r in datos_alcaldes.CANTON_NOMBRE.unique():
    tupla = (r, r)
    lista_op.append(tupla)

print(lista_op)
"""
# Out:
# '\nlista_op = []\nfor r in datos_alcaldes.CANTON_NOMBRE.unique():\n    tupla = (r, r)\n    lista_op.append(tupla)\n\nprint(lista_op)\n'

# %%
print(opciones)
# Out:
# [('24 DE MAYO', '24 DE MAYO'), ('A.BAQUERIZO MORENO', 'A.BAQUERIZO MORENO'), ('AGUARICO', 'AGUARICO'), ('ALAUSI', 'ALAUSI'), ('AMBATO', 'AMBATO'), ('ANTONIO ANTE', 'ANTONIO ANTE'), ('ARAJUNO', 'ARAJUNO'), ('ARCHIDONA', 'ARCHIDONA'), ('ARENILLAS', 'ARENILLAS'), ('ATACAMES', 'ATACAMES'), ('ATAHUALPA', 'ATAHUALPA'), ('AZOGUES', 'AZOGUES'), ('BABA', 'BABA'), ('BABAHOYO', 'BABAHOYO'), ('BALAO', 'BALAO'), ('BALSAS', 'BALSAS'), ('BALZAR', 'BALZAR'), ('BAÑOS', 'BAÑOS'), ('BIBLIAN', 'BIBLIAN'), ('BOLIVAR', 'BOLIVAR'), ('BUENA FE', 'BUENA FE'), ('C. J. AROSEMENA TOLA', 'C. J. AROSEMENA TOLA'), ('CALUMA', 'CALUMA'), ('CALVAS', 'CALVAS'), ('CAMILO PONCE ENRIQUEZ', 'CAMILO PONCE ENRIQUEZ'), ('CASCALES', 'CASCALES'), ('CATAMAYO', 'CATAMAYO'), ('CAYAMBE', 'CAYAMBE'), ('CAÑAR', 'CAÑAR'), ('CELICA', 'CELICA'), ('CENTINELA DEL CONDOR', 'CENTINELA DEL CONDOR'), ('CEVALLOS', 'CEVALLOS'), ('CHAGUARPAMBA', 'CHAGUARPAMBA'), ('CHAMBO', 'CHAMBO'), ('CHILLA', 'CHILLA'), ('CHILLANES', 'CHILLANES'), ('CHIMBO', 
# ...

# %%
canton = widgets.Dropdown(
    # options=[('LOJA', "LOJA"), ("CATAMAYO", "CATAMAYO"), ("PINDAL", "PINDAL")],
    options = opciones,
    value="LOJA",
    description='Cantón:',
)

canton
# Out:
# Dropdown(description='Cantón:', index=97, options=(('24 DE MAYO', '24 DE MAYO'), ('A.BAQUERIZO MORENO', 'A.BAQ…

# %%
datos_x_canton = datos_alcaldes[datos_alcaldes['CANTON_NOMBRE']==canton.value]
datos_x_canton.head(10)
# Out:
#       DIGNIDAD_CODIGO DIGNIDAD_NOMBRE  PROVINCIA_CODIGO PROVINCIA_NOMBRE  \
# 8958              4.0         ALCALDE              11.0             LOJA
# 8959              4.0         ALCALDE              11.0             LOJA
# 8960              4.0         ALCALDE              11.0             LOJA
# 8961              4.0         ALCALDE              11.0             LOJA
# 8962              4.0         ALCALDE              11.0             LOJA
# 8963              4.0         ALCALDE              11.0             LOJA
# 8964              4.0         ALCALDE              11.0             LOJA
# 8965              4.0         ALCALDE              11.0             LOJA
# 8966              4.0         ALCALDE              11.0             LOJA
# 8967              4.0         ALCALDE              11.0             LOJA
#
#       CANTON_CODIGO CANTON_NOMBRE  CIRCUNSCRIPCION_CODIGO  \
# 8958          340.0     ESPINDOLA                     0.0
# ...

# %%
datos_x_canton.groupby("CANDIDATO_NOMBRE")['VOTOS'].sum().sort_values(ascending=False).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='CANDIDATO_NOMBRE'>
