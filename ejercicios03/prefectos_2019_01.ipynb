# %%
# generar el proceso para prefectos 


# permitir buscar por provincias

# %%
import pandas as pd
import ipywidgets as widgets

# %%
datos_prefectos = pd.read_csv('data/datos_prefectos_2019_modificado.csv', sep="|")

# %%
datos_candidatos = pd.read_spss('data/candidatos2019.sav')

# %%
datos_prefectos2.to_csv("data/datos_prefectos_2019_modificado.csv", sep="|", index=False)

# %%
datos_candidatos_2 = datos_candidatos[['CANDIDATO_CODIGO', 'CANDIDATO_NOMBRE', 'OP_CODIGO']]

# %%
datos_prefectos2 = pd.merge(datos_prefectos, datos_candidatos_2, on="CANDIDATO_CODIGO")

# %%
organizaciones_polticas = pd.read_spss("data/organizacionespolticas2019.sav")

# %%
organizaciones_polticas_2 = organizaciones_polticas[['OP_CODIGO', 'OP_NOMBRE']]

# %%
datos_prefectos2 =  pd.merge(datos_prefectos2 , organizaciones_polticas_2, on="OP_CODIGO")

# %%
datos_prefectos.keys()
# Out:
# Index(['DIGNIDAD_CODIGO', 'DIGNIDAD_NOMBRE', 'PROVINCIA_CODIGO',
#        'PROVINCIA_NOMBRE', 'CANTON_CODIGO', 'CANTON_NOMBRE',
#        'CIRCUNSCRIPCION_CODIGO', 'CICUNSCRIPCION_NOMBRE', 'CIRCUNSCRIPCION',
#        'PARROQUIA_CODIGO', 'PARROQUIA_NOMBRE', 'JUNTA_SEXO',
#        'CANDIDATO_CODIGO', 'SUFRAGANTES', 'BLANCOS', 'NULOS', 'VOTOS',
#        'CANDIDATO_NOMBRE', 'OP_CODIGO', 'OP_NOMBRE'],
#       dtype='object')

# %%
opciones = [(d, d) for d in datos_prefectos.PROVINCIA_NOMBRE.unique()]
opciones.sort()

# %%
provincia = widgets.Dropdown(
    options = opciones,
    value="LOJA",
    description='Provincia:',
)
provincia
# Out:
# Dropdown(description='Provincia:', index=10, options=(('AZUAY', 'AZUAY'), ('BOLÍVAR', 'BOLÍVAR'), ('CARCHI', '…

# %%
datos_x_canton = datos_prefectos[datos_prefectos['PROVINCIA_NOMBRE']==provincia.value]
datos_x_canton.head(10)
# Out:
#       DIGNIDAD_CODIGO          DIGNIDAD_NOMBRE  PROVINCIA_CODIGO  \
# 6558              2.0  PREFECTO Y VICEPREFECTO              11.0
# 6559              2.0  PREFECTO Y VICEPREFECTO              11.0
# 6560              2.0  PREFECTO Y VICEPREFECTO              11.0
# 6561              2.0  PREFECTO Y VICEPREFECTO              11.0
# 6562              2.0  PREFECTO Y VICEPREFECTO              11.0
# 6563              2.0  PREFECTO Y VICEPREFECTO              11.0
# 6564              2.0  PREFECTO Y VICEPREFECTO              11.0
# 6565              2.0  PREFECTO Y VICEPREFECTO              11.0
# 6566              2.0  PREFECTO Y VICEPREFECTO              11.0
# 6567              2.0  PREFECTO Y VICEPREFECTO              11.0
#
#      PROVINCIA_NOMBRE  CANTON_CODIGO CANTON_NOMBRE  CIRCUNSCRIPCION_CODIGO  \
# 6558             LOJA          290.0      CATAMAYO                     0.0
# 6559             LOJA          290.0      CATAMAYO                     0.0
# 6560             LOJA          290.0      CATAMAYO                     0.0
# 6561             LOJA          290.0      CATAMAYO                     0.0
# 6562             LOJA          290.0      CATAMAYO                     0.0
# 6563             LOJA          290.0      CATAMAYO                     0.0
# 6564             LOJA          290.0      CATAMAYO                     0.0
# 6565             LOJA          290.0      CATAMAYO                     0.0
# 6566             LOJA          290.0      CATAMAYO                     0.0
# 6567             LOJA          290.0      CATAMAYO                     0.0
#
#       CICUNSCRIPCION_NOMBRE CIRCUNSCRIPCION  PARROQUIA_CODIGO  \
# 6558                    0.0             NaN            1200.0
# 6559                    0.0             NaN            1200.0
# 6560                    0.0             NaN            1480.0
# 6561                    0.0             NaN            1480.0
# 6562                    0.0             NaN            3610.0
# 6563                    0.0             NaN            3610.0
# 6564                    0.0             NaN            4455.0
# 6565                    0.0             NaN            4455.0
# 6566                    0.0             NaN            5270.0
# 6567                    0.0             NaN            5270.0
#
#              PARROQUIA_NOMBRE JUNTA_SEXO  CANDIDATO_CODIGO  SUFRAGANTES  \
# 6558                 EL TAMBO          F           36045.0       1060.0
# 6559                 EL TAMBO          M           36045.0       1129.0
# 6560             GUAYQUICHUMA          F           36045.0        133.0
# 6561             GUAYQUICHUMA          M           36045.0        186.0
# 6562  SAN PEDRO DE LA BENDITA          F           36045.0        631.0
# 6563  SAN PEDRO DE LA BENDITA          M           36045.0        616.0
# 6564                    ZAMBI          F           36045.0        198.0
# 6565                    ZAMBI          M           36045.0        203.0
# 6566                 CATAMAYO          F           36045.0       9009.0
# 6567                 CATAMAYO          M           36045.0       8290.0
#
#       BLANCOS  NULOS  VOTOS CANDIDATO_NOMBRE  OP_CODIGO  \
# 6558    190.0   83.0   40.0      MAX IÑIGUEZ      148.0
# 6559    188.0  102.0   42.0      MAX IÑIGUEZ      148.0
# 6560     21.0   15.0    2.0      MAX IÑIGUEZ      148.0
# 6561     32.0    9.0    5.0      MAX IÑIGUEZ      148.0
# 6562     56.0   44.0   26.0      MAX IÑIGUEZ      148.0
# 6563     66.0   66.0   25.0      MAX IÑIGUEZ      148.0
# 6564     29.0   11.0    7.0      MAX IÑIGUEZ      148.0
# 6565     37.0   12.0    5.0      MAX IÑIGUEZ      148.0
# 6566    873.0  666.0  687.0      MAX IÑIGUEZ      148.0
# 6567    949.0  679.0  661.0      MAX IÑIGUEZ      148.0
#
#                             OP_NOMBRE
# 6558  MOVIMIENTO F. COMPROMISO SOCIAL
# 6559  MOVIMIENTO F. COMPROMISO SOCIAL
# 6560  MOVIMIENTO F. COMPROMISO SOCIAL
# 6561  MOVIMIENTO F. COMPROMISO SOCIAL
# 6562  MOVIMIENTO F. COMPROMISO SOCIAL
# 6563  MOVIMIENTO F. COMPROMISO SOCIAL
# 6564  MOVIMIENTO F. COMPROMISO SOCIAL
# 6565  MOVIMIENTO F. COMPROMISO SOCIAL
# 6566  MOVIMIENTO F. COMPROMISO SOCIAL
# 6567  MOVIMIENTO F. COMPROMISO SOCIAL

# %%
datos_x_canton.groupby("CANDIDATO_NOMBRE")['VOTOS'].sum().sort_values(ascending=False).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='CANDIDATO_NOMBRE'>
